# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize = (2,2))

# %%
path = "/Users/elliott/Documents/Personal_Projects/medic_calls.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0 unit_id  incident_number         call_type   call_date  \
# 0           1    KM07       19118384.0  Medical Incident  10/02/2019
# 1           4      83       19118381.0  Medical Incident  10/02/2019
# 2           9      94       19118376.0  Medical Incident  10/02/2019
# 3          13      82       19118377.0  Medical Incident  10/02/2019
# 4          14      62       19118375.0  Medical Incident  10/02/2019
#
#             received_dttm              entry_dttm           dispatch_dttm  \
# 0  10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM  10/02/2019 11:52:43 PM
# 1  10/02/2019 11:33:58 PM  10/02/2019 11:36:27 PM  10/02/2019 11:36:46 PM
# 2  10/02/2019 11:24:10 PM  10/02/2019 11:25:39 PM  10/02/2019 11:25:54 PM
# 3  10/02/2019 11:22:51 PM  10/02/2019 11:26:54 PM  10/02/2019 11:27:06 PM
# 4  10/02/2019 11:22:50 PM  10/02/2019 11:24:25 PM  10/02/2019 11:24:53 PM
#
#             response_dttm           on_scene_dttm          transport_dttm  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                int64
# unit_id                                  object
# incident_number                         float64
# call_type                                object
# call_date                                object
# received_dttm                            object
# entry_dttm                               object
# dispatch_dttm                            object
# response_dttm                            object
# on_scene_dttm                            object
# transport_dttm                           object
# hospital_dttm                            object
# call_final_disposition                   object
# available_dttm                           object
# address                                  object
# city                                     object
# zipcode_of_incident                     float64
# station_area                             object
# box                                      object
# original_priority                        object
# ...

# %%
df['dispatch_dttm'] = pd.to_datetime(df['dispatch_dttm'])

# %%
df['entry_dttm'] = pd.to_datetime(df['entry_dttm'])

# %%
df.dtypes
# Out:
# Unnamed: 0                                       int64
# unit_id                                         object
# incident_number                                float64
# call_type                                       object
# call_date                                       object
# received_dttm                                   object
# entry_dttm                              datetime64[ns]
# dispatch_dttm                           datetime64[ns]
# response_dttm                                   object
# on_scene_dttm                                   object
# transport_dttm                                  object
# hospital_dttm                                   object
# call_final_disposition                          object
# available_dttm                                  object
# address                                         object
# city                                            object
# zipcode_of_incident                            float64
# ...

# %%
forPlot = df.groupby([df['dispatch_dttm'].dt.date]).count()

# %%
forPlot.head()
# Out:
#                Unnamed: 0  unit_id  incident_number  call_type  call_date  \
# dispatch_dttm
# 2015-08-17            298      298              298        298        298
# 2015-08-18            291      291              291        291        291
# 2015-08-19            309      309              309        309        309
# 2015-08-20            275      275              275        275        275
# 2015-08-21            298      298              298        298        298
#
#                received_dttm  entry_dttm  dispatch_dttm  response_dttm  \
# dispatch_dttm
# 2015-08-17               298         298            298            293
# 2015-08-18               291         291            291            287
# 2015-08-19               309         309            309            305
# 2015-08-20               275         275            275            272
# 2015-08-21               298         298            298            291
#
# ...

# %%
forPlot.index.name='Date'

# %%
forPlot.head()
# Out:
#             Unnamed: 0  unit_id  incident_number  call_type  call_date  \
# Date
# 2015-08-17         298      298              298        298        298
# 2015-08-18         291      291              291        291        291
# 2015-08-19         309      309              309        309        309
# 2015-08-20         275      275              275        275        275
# 2015-08-21         298      298              298        298        298
#
#             received_dttm  entry_dttm  dispatch_dttm  response_dttm  \
# Date
# 2015-08-17            298         298            298            293
# 2015-08-18            291         291            291            287
# 2015-08-19            309         309            309            305
# 2015-08-20            275         275            275            272
# 2015-08-21            298         298            298            291
#
#             on_scene_dttm  ...  zipcode_of_incident  station_area  box  \
# Date                       ...
# ...

# %%
forPlot.index = pd.to_datetime(forPlot.index)
forPlot.index
# Out:
# DatetimeIndex(['2015-08-17', '2015-08-18', '2015-08-19', '2015-08-20',
#                '2015-08-21', '2015-08-22', '2015-08-23', '2015-08-24',
#                '2015-08-25', '2015-08-26',
#                ...
#                '2019-09-23', '2019-09-24', '2019-09-25', '2019-09-26',
#                '2019-09-27', '2019-09-28', '2019-09-29', '2019-09-30',
#                '2019-10-01', '2019-10-02'],
#               dtype='datetime64[ns]', name='Date', length=1507, freq=None)

# %%
forPlot = forPlot.loc['2016-09-01':'2019-09-30']

# %%
forPlot.head()
# Out:
#             Unnamed: 0  unit_id  incident_number  call_type  call_date  \
# Date
# 2016-09-01         347      347              347        347        347
# 2016-09-02         401      401              401        401        401
# 2016-09-03         341      341              341        341        341
# 2016-09-04         317      317              317        317        317
# 2016-09-05         328      328              328        328        328
#
#             received_dttm  entry_dttm  dispatch_dttm  response_dttm  \
# Date
# 2016-09-01            347         347            347            335
# 2016-09-02            401         401            401            392
# 2016-09-03            341         341            341            337
# 2016-09-04            317         317            317            315
# 2016-09-05            328         328            328            319
#
#             on_scene_dttm  ...  zipcode_of_incident  station_area  box  \
# Date                       ...
# ...

# %%
forPlot.tail()
# Out:
#             Unnamed: 0  unit_id  incident_number  call_type  call_date  \
# Date
# 2019-09-26         445      445              445        445        445
# 2019-09-27         392      392              392        392        392
# 2019-09-28         380      380              380        380        380
# 2019-09-29         389      389              389        389        389
# 2019-09-30         378      378              378        378        378
#
#             received_dttm  entry_dttm  dispatch_dttm  response_dttm  \
# Date
# 2019-09-26            445         445            445            439
# 2019-09-27            392         392            392            384
# 2019-09-28            380         380            380            372
# 2019-09-29            389         389            389            380
# 2019-09-30            378         378            378            373
#
#             on_scene_dttm  ...  zipcode_of_incident  station_area  box  \
# Date                       ...
# ...

# %%
check = forPlot[['dispatch_dttm']].copy()

# %%
weather = pd.read_csv('/Users/elliott/Documents/Personal_Projects/WeatherData/compiledWeather.csv')

# %%
weather.head()
# Out:
#    Unnamed: 0        Date  Maximum  Minimum  Average Precipitation   Weekday
# 0           0  2016-09-01       68       58     63.0           0.0  Thursday
# 1           1  2016-09-02       71       55     63.0           0.0    Friday
# 2           2  2016-09-03       66       57     61.5           0.0  Saturday
# 3           3  2016-09-04       67       56     61.5           0.0    Sunday
# 4           4  2016-09-05       72       53     62.5           0.0    Monday

# %%
weather.drop('Unnamed: 0', axis=1)
# Out:
#             Date  Maximum  Minimum  Average Precipitation    Weekday
# 0     2016-09-01       68       58     63.0           0.0   Thursday
# 1     2016-09-02       71       55     63.0           0.0     Friday
# 2     2016-09-03       66       57     61.5           0.0   Saturday
# 3     2016-09-04       67       56     61.5           0.0     Sunday
# 4     2016-09-05       72       53     62.5           0.0     Monday
# 5     2016-09-06       84       54     69.0           0.0    Tuesday
# 6     2016-09-07       88       58     73.0           0.0  Wednesday
# 7     2016-09-08       73       57     65.0           0.0   Thursday
# 8     2016-09-09       67       56     61.5           0.0     Friday
# 9     2016-09-10       67       55     61.0           0.0   Saturday
# 10    2016-09-11       71       55     63.0           0.0     Sunday
# 11    2016-09-12       66       54     60.0           0.0     Monday
# 12    2016-09-13       71       56     63.5           0.0    Tuesday
# ...

# %%
weather = weather.set_index('Date')

# %%
weather = weather.drop(columns = ['Unnamed: 0'])

# %%
weather.head()
# Out:
#             Maximum  Minimum  Average Precipitation   Weekday  \
# Date
# 2016-09-01       68       58     63.0           0.0  Thursday
# 2016-09-02       71       55     63.0           0.0    Friday
# 2016-09-03       66       57     61.5           0.0  Saturday
# 2016-09-04       67       56     61.5           0.0    Sunday
# 2016-09-05       72       53     62.5           0.0    Monday
#
#             Dispatched_calls
# Date
# 2016-09-01               347
# 2016-09-02               401
# 2016-09-03               341
# 2016-09-04               317
# 2016-09-05               328

# %%
weather['Precipitation']= weather['Precipitation'].replace(to_replace=['NaN'],value=np.NaN)

# %%
weather.isna().sum()
# Out:
# Maximum              0
# Minimum              0
# Average              0
# Precipitation       20
# Weekday              0
# Dispatched_calls     0
# dtype: int64

# %%
weather.index[weather['Precipitation']=='NaN'].tolist()
# Out:
# []

# %%
weather['weekday_num']= weather.index.dayofweek

# %%
weather['Precipitation'] = weather['Precipitation'].astype(float)

# %%
weather.dtypes
# Out:
# Maximum               int64
# Minimum               int64
# Average             float64
# Precipitation       float64
# Weekday              object
# Dispatched_calls      int64
# weekday_num           int64
# dtype: object

# %%
weather.plot(y='Precipitation', grid=True, figsize = (20,12))

# %%
forPlot.plot(y='call_type', grid=True, figsize = (20,12))

# %%
x = check.index.date[1]

# %%
y = weather.index.date[1]

# %%
x ==y
# Out:
# True

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather = weather[['Maximum','Minimum','Average','Precipitation','Weekday','weekday_num', 'Dispatched_calls']]

# %%
weather.head()
# Out:
#             Maximum  Minimum  Average  Precipitation   Weekday  weekday_num  \
# Date
# 2016-09-01       68       58     63.0            0.0  Thursday            3
# 2016-09-02       71       55     63.0            0.0    Friday            4
# 2016-09-03       66       57     61.5            0.0  Saturday            5
# 2016-09-04       67       56     61.5            0.0    Sunday            6
# 2016-09-05       72       53     62.5            0.0    Monday            0
#
#             Dispatched_calls
# Date
# 2016-09-01               347
# 2016-09-02               401
# 2016-09-03               341
# 2016-09-04               317
# 2016-09-05               328

# %%
for i in range(1125):
    if weather.index.date[i]!= check.index.date[i]:
        print (i)
# Out:
# 862
# 863
# 864
# 865
# 866
# 867
# 868
# 869
# 870
# 871
# 872
# 873
# 874
# 875
# 876
# 877
# 878
# 879
# 880
# 881
# 882
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
# 914
# 915
# 916
# 917
# 918
# 919
# 920
# 921
# 922
# 923
# 924
# 925
# 926
# 927
# 928
# 929
# 930
# 931
# 932
# 933
# 934
# 935
# 936
# 937
# 938
# 939
# 940
# 941
# 942
# 943
# 944
# 945
# 946
# 947
# 948
# 949
# 950
# 951
# 952
# 953
# 954
# 955
# 956
# 957
# 958
# 959
# 960
# 961
# 962
# 963
# 964
# 965
# 966
# 967
# 968
# 969
# 970
# 971
# 972
# 973
# 974
# 975
# 976
# 977
# 978
# 979
# 980
# 981
# 982
# 983
# 984
# 985
# 986
# 987
# 988
# 989
# 990
# 991
# 992
# 993
# 994
# 995
# 996
# 997
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# ...

# %%
weather.index[862]
# Out:
# Timestamp('2019-01-11 00:00:00')

# %%
check.index[862]
# Out:
# Timestamp('2019-01-12 00:00:00')

# %%
weather.index[861]
# Out:
# Timestamp('2019-01-10 00:00:00')

# %%
check.index[861]
# Out:
# Timestamp('2019-01-10 00:00:00')

# %% [markdown]
# There is a missing date in the check database between 1-10-2019 and 1-12-2019

# %%
check.head()
# Out:
#             dispatch_dttm
# Date
# 2016-09-01            347
# 2016-09-02            401
# 2016-09-03            341
# 2016-09-04            317
# 2016-09-05            328

# %%
check[860:864]
# Out:
#             dispatch_dttm
# Date
# 2019-01-09            340
# 2019-01-10              1
# 2019-01-12            319
# 2019-01-13            326

# %%
check.dtypes
# Out:
# dispatch_dttm    int64
# dtype: object

# %%
time = pd.datetime('2019-01-11')
# Out:
#   File "<ipython-input-264-d079ea2f408b>", line 1
#     time = pd.datetime(2019-01-11)
#                              ^
# SyntaxError: invalid token

# %%
data = {'dispatch_dttm': 1}
# check.DatetimeIndex.insert(862,time)
check = check.append(pd.DataFrame(data,index=[time]))

# %%
check.index
# Out:
# DatetimeIndex(['2016-09-01', '2016-09-02', '2016-09-03', '2016-09-04',
#                '2016-09-05', '2016-09-06', '2016-09-07', '2016-09-08',
#                '2016-09-09', '2016-09-10',
#                ...
#                '2019-09-22', '2019-09-23', '2019-09-24', '2019-09-25',
#                '2019-09-26', '2019-09-27', '2019-09-28', '2019-09-29',
#                '2019-09-30', '2019-01-11'],
#               dtype='datetime64[ns]', length=1125, freq=None)

# %%
check = check.sort_index()

# %%
check[860:865]
# Out:
#             dispatch_dttm
# 2019-01-09            340
# 2019-01-10              1
# 2019-01-11              1
# 2019-01-12            319
# 2019-01-13            326

# %%
frames = [check, weather]

# %%
lframe = pd.concat(frames)
# Out:
# /Users/elliott/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
weather
# Out:
#             Unnamed: 0  Maximum  Minimum  Average Precipitation    Weekday
# Date
# 2016-09-01           0       68       58     63.0           0.0   Thursday
# 2016-09-02           1       71       55     63.0           0.0     Friday
# 2016-09-03           2       66       57     61.5           0.0   Saturday
# 2016-09-04           3       67       56     61.5           0.0     Sunday
# 2016-09-05           4       72       53     62.5           0.0     Monday
# 2016-09-06           5       84       54     69.0           0.0    Tuesday
# 2016-09-07           6       88       58     73.0           0.0  Wednesday
# 2016-09-08           7       73       57     65.0           0.0   Thursday
# 2016-09-09           8       67       56     61.5           0.0     Friday
# 2016-09-10           9       67       55     61.0           0.0   Saturday
# 2016-09-11          10       71       55     63.0           0.0     Sunday
# ...

# %%
weather['Dispatched_calls'] = check['dispatch_dttm']

# %%
weather.head()
# Out:
#             Unnamed: 0  Maximum  Minimum  Average Precipitation   Weekday  \
# Date
# 2016-09-01           0       68       58     63.0           0.0  Thursday
# 2016-09-02           1       71       55     63.0           0.0    Friday
# 2016-09-03           2       66       57     61.5           0.0  Saturday
# 2016-09-04           3       67       56     61.5           0.0    Sunday
# 2016-09-05           4       72       53     62.5           0.0    Monday
#
#             Dispatched_calls
# Date
# 2016-09-01               347
# 2016-09-02               401
# 2016-09-03               341
# 2016-09-04               317
# 2016-09-05               328

# %%
check.tail()
# Out:
#             dispatch_dttm
# 2019-09-26            445
# 2019-09-27            392
# 2019-09-28            380
# 2019-09-29            389
# 2019-09-30            378

# %%
weather.tail()
# Out:
#             Unnamed: 0  Maximum  Minimum  Average Precipitation   Weekday  \
# Date
# 2019-09-26        1120       77       60     68.5           0.0  Thursday
# 2019-09-27        1121       64       56     60.0          0.03    Friday
# 2019-09-28        1122       63       53     58.0           0.0  Saturday
# 2019-09-29        1123       64       52     58.0           0.0    Sunday
# 2019-09-30        1124       62       54     58.0           0.0    Monday
#
#             Dispatched_calls
# Date
# 2019-09-26               445
# 2019-09-27               392
# 2019-09-28               380
# 2019-09-29               389
# 2019-09-30               378

# %%
weather.to_csv('/Users/elliott/Documents/Personal_Projects/calls_weather_week.csv')
