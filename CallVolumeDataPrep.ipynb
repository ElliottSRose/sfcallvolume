# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/Users/elliott/Documents/Personal_Projects/Fire_Department_Calls_for_Service.csv"
df = pd.read_csv(path)
df.head()
# Out:
#   Call Number Unit ID  Incident Number                      Call Type  \
# 0   192754541     E31       19118384.0               Medical Incident
# 1   192754541    KM07       19118384.0               Medical Incident
# 2   192754532     E31       19118383.0  Citizen Assist / Service Call
# 3   192754527     E08       19118382.0                   Outside Fire
# 4   192754509      83       19118381.0               Medical Incident
#
#     Call Date  Watch Date           Received DtTm              Entry DtTm  \
# 0  10/02/2019  10/02/2019  10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM
# 1  10/02/2019  10/02/2019  10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM
# 2  10/02/2019  10/02/2019  10/02/2019 11:44:29 PM  10/02/2019 11:46:04 PM
# 3  10/02/2019  10/02/2019  10/02/2019 11:42:57 PM  10/02/2019 11:44:29 PM
# 4  10/02/2019  10/02/2019  10/02/2019 11:33:58 PM  10/02/2019 11:36:27 PM
#
#             Dispatch DtTm           Response DtTm  ... ALS Unit  \
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Call Number  Unit ID  Incident Number  Call Type  Call Date  Watch Date  \
# 0        False    False            False      False      False       False
# 1        False    False            False      False      False       False
# 2        False    False            False      False      False       False
# 3        False    False            False      False      False       False
# 4        False    False            False      False      False       False
#
#    Received DtTm  Entry DtTm  Dispatch DtTm  Response DtTm  ...  ALS Unit  \
# 0          False       False          False          False  ...     False
# 1          False       False          False          False  ...     False
# 2          False       False          False          False  ...     False
# 3          False       False          False          False  ...     False
# 4          False       False          False          False  ...     False
#
#    Call Type Group  Number of Alarms  Unit Type  \
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Call Number
# False    1276368
# Name: Call Number, dtype: int64
#
# Unit ID
# False    1276364
# True           4
# Name: Unit ID, dtype: int64
#
# Incident Number
# False    1276364
# True           4
# Name: Incident Number, dtype: int64
#
# Call Type
# False    1276364
# True           4
# Name: Call Type, dtype: int64
#
# Call Date
# False    1276364
# True           4
# Name: Call Date, dtype: int64
#
# Watch Date
# False    1276364
# True           4
# Name: Watch Date, dtype: int64
#
# Received DtTm
# False    1276364
# True           4
# Name: Received DtTm, dtype: int64
#
# Entry DtTm
# False    1276364
# True           4
# Name: Entry DtTm, dtype: int64
#
# Dispatch DtTm
# False    1276364
# True           4
# Name: Dispatch DtTm, dtype: int64
#
# Response DtTm
# False    1243391
# True       32977
# Name: Response DtTm, dtype: int64
#
# On Scene DtTm
# False    1025653
# True      250715
# Name: On Scene DtTm, dtype: int64
#
# Transport DtTm
# True     912656
# ...

# %% [markdown]
# Now we need to reformat the column headers to make them easier to work with.

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df.drop(['call_number','watch_date','number_of_alarms','unit_sequence_in_call_dispatch','fire_prevention_district','supervisor_district','battalion','location','rowid'], axis=1, inplace = True)
df.head()
# Out:
#   unit_id  incident_number                      call_type   call_date  \
# 0     E31       19118384.0               Medical Incident  10/02/2019
# 1    KM07       19118384.0               Medical Incident  10/02/2019
# 2     E31       19118383.0  Citizen Assist / Service Call  10/02/2019
# 3     E08       19118382.0                   Outside Fire  10/02/2019
# 4      83       19118381.0               Medical Incident  10/02/2019
#
#             received_dttm              entry_dttm           dispatch_dttm  \
# 0  10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM  10/03/2019 12:16:14 AM
# 1  10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM  10/02/2019 11:52:43 PM
# 2  10/02/2019 11:44:29 PM  10/02/2019 11:46:04 PM  10/02/2019 11:46:25 PM
# 3  10/02/2019 11:42:57 PM  10/02/2019 11:44:29 PM  10/02/2019 11:45:44 PM
# 4  10/02/2019 11:33:58 PM  10/02/2019 11:36:27 PM  10/02/2019 11:36:46 PM
#
#             response_dttm           on_scene_dttm          transport_dttm  \
# ...

# %% [markdown]
# Check for NaNs in the row of concern as they are causing errors for editing the dataframe.

# %%
df['unit_type'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1276338    False
# 1276339    False
# 1276340    False
# 1276341    False
# 1276342    False
# 1276343    False
# 1276344    False
# 1276345    False
# 1276346    False
# 1276347    False
# 1276348    False
# 1276349    False
# 1276350    False
# 1276351    False
# 1276352    False
# 1276353    False
# 1276354    False
# 1276355    False
# 1276356    False
# 1276357    False
# 1276358    False
# ...

# %%
df.tail(10)
# Out:
#         unit_id  incident_number         call_type   call_date  \
# 1276358      88       15087235.0  Medical Incident  08/17/2015
# 1276359     E51       15087235.0  Medical Incident  08/17/2015
# 1276360     E15       15087233.0  Medical Incident  08/17/2015
# 1276361      75       15087233.0  Medical Incident  08/17/2015
# 1276362      55       15087231.0  Medical Incident  08/17/2015
# 1276363      71       15087230.0  Medical Incident  08/17/2015
# 1276364     NaN              NaN               NaN         NaN
# 1276365     NaN              NaN               NaN         NaN
# 1276366     NaN              NaN               NaN         NaN
# 1276367     NaN              NaN               NaN         NaN
#
#                   received_dttm              entry_dttm  \
# 1276358  08/17/2015 01:18:13 AM  08/17/2015 01:22:30 AM
# 1276359  08/17/2015 01:18:13 AM  08/17/2015 01:22:30 AM
# 1276360  08/17/2015 01:17:41 AM  08/17/2015 01:18:33 AM
# ...

# %% [markdown]
# We should drop the last rows that are full of NaNs

# %%
df.dropna(how='all')
# Out:
#         unit_id  incident_number                      call_type   call_date  \
# 0           E31       19118384.0               Medical Incident  10/02/2019
# 1          KM07       19118384.0               Medical Incident  10/02/2019
# 2           E31       19118383.0  Citizen Assist / Service Call  10/02/2019
# 3           E08       19118382.0                   Outside Fire  10/02/2019
# 4            83       19118381.0               Medical Incident  10/02/2019
# 5           T13       19118379.0                         Alarms  10/02/2019
# 6           B01       19118379.0                         Alarms  10/02/2019
# 7           E13       19118379.0                         Alarms  10/02/2019
# 8           E02       19118380.0                   Outside Fire  10/02/2019
# 9            94       19118376.0               Medical Incident  10/02/2019
# 10          T01       19118378.0                         Alarms  10/02/2019
# ...

# %%
filtered = df.unit_type.str.contains('MEDIC|PRIVATE', na=False)
newdf= df[filtered]

# %%
newdf.head()
# Out:
#    unit_id  incident_number         call_type   call_date  \
# 1     KM07       19118384.0  Medical Incident  10/02/2019
# 4       83       19118381.0  Medical Incident  10/02/2019
# 9       94       19118376.0  Medical Incident  10/02/2019
# 13      82       19118377.0  Medical Incident  10/02/2019
# 14      62       19118375.0  Medical Incident  10/02/2019
#
#              received_dttm              entry_dttm           dispatch_dttm  \
# 1   10/02/2019 11:51:00 PM  10/02/2019 11:52:30 PM  10/02/2019 11:52:43 PM
# 4   10/02/2019 11:33:58 PM  10/02/2019 11:36:27 PM  10/02/2019 11:36:46 PM
# 9   10/02/2019 11:24:10 PM  10/02/2019 11:25:39 PM  10/02/2019 11:25:54 PM
# 13  10/02/2019 11:22:51 PM  10/02/2019 11:26:54 PM  10/02/2019 11:27:06 PM
# 14  10/02/2019 11:22:50 PM  10/02/2019 11:24:25 PM  10/02/2019 11:24:53 PM
#
#              response_dttm           on_scene_dttm          transport_dttm  \
# 1   10/02/2019 11:53:18 PM  10/02/2019 11:57:59 PM  10/03/2019 12:41:08 AM
# ...

# %%
newdf.to_csv('medic_calls.csv')
